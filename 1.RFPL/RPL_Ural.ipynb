# %%
#грузим либы
import pandas as pd
from IPython.display import display

# %%
#загружаем данные
rpl_data = pd.read_csv('rpl_events.csv',sep = ",",index_col = 0)
# Out:
# /Users/dmitrii/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (2,32,36,37,43,44,45,46,48,61,88,89,91,92,94,96,117,118,120,121,122,123) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#смотрим на таблицу полную
display(rpl_data.head(1))
# Out:
#                                                     50_50 bad_behaviour_card  \
# index
# 0,,,,,,,,,,,,,,,,,,,,,,,0.0,,,,,,,,,,,,,,,,,,,,...    NaN                NaN
#
#                                                     ball_receipt_outcome  \
# index
# 0,,,,,,,,,,,,,,,,,,,,,,,0.0,,,,,,,,,,,,,,,,,,,,...                   NaN
#
#                                                     ball_recovery_offensive  \
# index
# 0,,,,,,,,,,,,,,,,,,,,,,,0.0,,,,,,,,,,,,,,,,,,,,...                      NaN
#
#                                                     ball_recovery_recovery_failure  \
# index
# 0,,,,,,,,,,,,,,,,,,,,,,,0.0,,,,,,,,,,,,,,,,,,,,...                             NaN
#
#                                                     block_deflection  \
# index
# 0,,,,,,,,,,,,,,,,,,,,,,,0.0,,,,,,,,,,,,,,,,,,,,...               NaN
#
#                                                     block_offensive  \
# index
# 0,,,,,,,,,,,,,,,,,,,,,,,0.0,,,,,,,,,,,,,,,,,,,,...              NaN
#
# ...

# %%
#смотрим как называется Урал
rpl_data.team.unique()
# Out:
# array(['Lokomotiv Moscow', 'Nizhny Novgorod', 'CSKA Moscow',
#        'Dinamo Moscow', 'Rostov', 'Spartak Moscow', 'FK AKHMAT GROZNY',
#        'Zenit St. Petersburg', 'Arsenal Tula',
#        'Fk Ural Sverdlovskaya Oblast', 'Krylya Sovetov', 'Fk Rubin Kazan',
#        'FK Krasnodar', 'Fk Khimki', 'Sochi', 'FC Ufa'], dtype=object)

# %%
#отбираем только Урал
ural_only = rpl_data.query('team == "Fk Ural Sverdlovskaya Oblast"')

# %%
#инфо по Уралу, 50к строк
ural_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51382 entries, 12 to 820611
# Columns: 123 entries, 50_50 to under_pressure
# dtypes: float64(14), int64(7), object(102)
# memory usage: 48.6+ MB

# %%
#смотрим пропуски, много строк с почти всеми пропущенными, мб стереть часть таких колонок, надо посмотреть, что за события в названиях колонок, и оставить только нужные нам
ural_only.isna().sum()
# Out:
# 50_50                             51359
# bad_behaviour_card                51373
# ball_receipt_outcome              49416
# ball_recovery_offensive           51376
# ball_recovery_recovery_failure    51286
#                                   ...
# tactics                           51332
# team                                  0
# timestamp                             0
# type                                  0
# under_pressure                    39513
# Length: 123, dtype: int64

# %%
#смотрим на числовые переменные
ural_only.describe()
# Out:
#            duration         index      match_id        minute  \
# count  38499.000000  51382.000000  5.138200e+04  51382.000000
# mean       1.207709   1802.602896  3.798546e+06     46.050232
# std        1.297535   1042.994668  7.007951e+01     27.207265
# min        0.000000      1.000000  3.798441e+06      0.000000
# 25%        0.176681    883.000000  3.798480e+06     22.000000
# 50%        0.977271   1814.000000  3.798537e+06     46.000000
# 75%        1.682482   2708.750000  3.798579e+06     70.000000
# max       30.470074   3909.000000  3.798676e+06     99.000000
#
#        obv_against_after  obv_against_before  obv_against_net  obv_for_after  \
# count       28926.000000        29062.000000     2.891700e+04   28926.000000
# mean            0.012974            0.013566    -6.982334e-04       0.019400
# std             0.035900            0.027509     2.570978e-02       0.026867
# min             0.003600            0.003646    -9.373665e-01       0.000000
# ...

# %%
#смотрим на таблу с Уралом
display(ural_only.head(10))
# Out:
#     50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 12    NaN                NaN                  NaN                     NaN
# 32    NaN                NaN                  NaN                     NaN
# 53    NaN                NaN                  NaN                     NaN
# 62    NaN                NaN                  NaN                     NaN
# 77    NaN                NaN                  NaN                     NaN
# 95    NaN                NaN                  NaN                     NaN
# 99    NaN                NaN                  NaN                     NaN
# 145   NaN                NaN                  NaN                     NaN
# 152   NaN                NaN                  NaN                     NaN
# 164   NaN                NaN                  NaN                     NaN
#
#     ball_recovery_recovery_failure block_deflection block_offensive  \
# 12                             NaN              NaN             NaN
# ...

# %%
#сохраняем таблицу с Уралом чтобы отправить тебе
ural_only.to_csv(r'ural_only.csv')

# %%
#тестово её загружаем обратно, чтобы проверить, что всё сохранилось
test = pd.read_csv('ural_only.csv',sep = ",",index_col = 0,low_memory=False)

# %%
#смотрим на таблу, вроде ок
display(test.head(10))
# Out:
#     50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 12    NaN                NaN                  NaN                     NaN
# 32    NaN                NaN                  NaN                     NaN
# 53    NaN                NaN                  NaN                     NaN
# 62    NaN                NaN                  NaN                     NaN
# 77    NaN                NaN                  NaN                     NaN
# 95    NaN                NaN                  NaN                     NaN
# 99    NaN                NaN                  NaN                     NaN
# 145   NaN                NaN                  NaN                     NaN
# 152   NaN                NaN                  NaN                     NaN
# 164   NaN                NaN                  NaN                     NaN
#
#     ball_recovery_recovery_failure block_deflection block_offensive  \
# 12                             NaN              NaN             NaN
# ...
